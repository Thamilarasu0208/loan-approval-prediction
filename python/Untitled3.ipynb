# %%
print("balaji")
# Out:
# balaji

# %%
a=10
b=20
c=a+b
print(a," ",b," ",c)
# Out:
# 10   20   30

# %%
a="20"
print(type(a))
# Out:
# <class 'str'>

# %%
a=int("29")
b=int("20")
c=a+b
print(c)
# Out:
# 49

# %%
a=int(input())
b=int(input())
c=a+b
print(c)
# Out:
#  10
#  20
# 30

# %%
a=int(input())
b=int(input())
c=a-b
print(c)
# Out:
#  20
#  10
# 10

# %%
name="tamil"
print(name)
# Out:
# tamil

# %%
name=input()
age=int(input())
add=input()
print("my name is",name)
print("my age is",age)
print("my address",add)
# Out:
#  bala
#  30
#  kallakurichi
# my name is bala
# my age is 30
# my address kallakurichi

# %%
a=int(input())
b=int(input())
c=int(input())
mul=a*b*c
add=a+b+c
div=mul/add
print(div)
# Out:
#  2
#  3
#  4
# 2.6666666666666665

# %%
name=input()
score=int(input())
dept=input()
print("my name is",name)
print("my score is",score/10)
print("my dept is",dept)
# Out:
#  gojo
#  80
#  cse
# my name is gojo
# my score is 8.0
# my dept is cse
