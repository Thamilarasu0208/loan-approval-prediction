# %%
rcb="winn"
if(rcb=="win"):
   print("Ee sala cupmnamde")
else:
    print("valakkam pola namakku cup illa  ")
# Out:
# valakkam pola namakku cup illa

# %%
Meghana=input()
if(Meghana=="Died"):
    print("Surya meets priya")
else:
    print("surya weds Meghana")
# Out:
#  Died
# Surya meets priya
