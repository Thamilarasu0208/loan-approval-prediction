# %%
a=float(input())
b=float(input())
print("1.add 2.sub 3.mul 4.div ")
add= a+b
sub=a-b
mul=a*b
div=a%b
result=input()
if(result=="add"):
    print(add)
elif(result=="sub"):
    print(sub)
elif(result=="mul"):
    print(mul)
elif(result=="div"):
    print(div)
else:
    print("enter valid selection")
# Out:
#  10
#  10
# 1.add 2.sub 3.mul 4.div
#  div
# 0.0

# %%
score=float(input("enter your score percentage without percentage symbol"))
if (score>70):
   name=input("enter your name")
   department=input("enter your dept")
   location=input("enter location")
   print("your are eligible")
else:
    print("you are not eligible")
# Out:
# enter your score percentage without percentage symbol 77
# enter your name thamilan
# enter your dept cse
# enter location tamilnadu
# your are eligible

# %%
salary=float(input("enter your salary:"))
age=int(input("enter your age:"))
if(salary>=20000 or age<=25):
    amount=float(input("enter loan amount:"))
    if(amount<=50000):
        print("you are eligible for loan")
    else:
        print("max loan amount is 50000")
else:
    print("not eligible for loan")
# Out:
# enter your salary: 22000
# enter your age: 20
# enter loan amount: 50000
# you are eligible for loan

# %%
a=float(input("enter 1st sub mark"))
b=float(input("enter 2nd sub mark"))
c=float(input("3rd mark"))
d=float(input("4th mark"))
e=float(input("5th mark"))
add=a+b+c+d+e
avg=add/5
if(avg<35):
    print("additional class is required")
else:
    print("you are good")
# Out:
# enter 1st sub mark 10
# enter 2nd sub mark 20
# 3rd mark 30
# 4th mark 40
# 5th mark 50
# additional class is required
